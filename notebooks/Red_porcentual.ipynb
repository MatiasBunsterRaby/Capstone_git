# %% [markdown]
# #### 21 Oct 2024
# #### Temas por revisar en este Notebook:
#
# *   * Acuerdo con profesora guía:
# *   * Red todos con todos, basado en %. Definir umbral y ver comunidades/ Clusters/ Definir un tema relevante
# *   * Similaridad vs Influencia
# *   * Check Pueblos Originarios/ peak/ en programas
# *   * Check DDHH/ en programas
# *   *
#
# ---

# %% [markdown]
# #### Cargar librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Markdown, display
import glob

# %% [markdown]
# #### Cargar archivos

# %% [markdown]
# #### Cargamos los programas *.csv en 'df_programas_Chile'

# %%
# Ruta a los archivos CSV
ruta_archivos = './data/Annotated_Chile/*.csv'

# Obtener la lista de archivos
archivos_csv = glob.glob(ruta_archivos)

# Verificar si se encontraron archivos
if not archivos_csv:
    print("No se encontraron archivos en la ruta especificada.")
else:
    print(f"Archivos encontrados: {archivos_csv}")

# Crear una lista para almacenar los DataFrames
dataframes = []

# Cargar los archivos al DataFrame
for archivo in archivos_csv:
    try:
        print(f"Leyendo archivo: {archivo}")
        df = pd.read_csv(
            archivo,
            encoding='utf-8',
            delimiter=',',
            skiprows=[1],  # Ignorar la primera fila después del encabezado
            names=['frase', 'frase_eng', 'cmp_code', 'eu_code'],  # Renombrar las columnas
            header=0,  # Ignorar los nombres originales de columnas
            keep_default_na=False,  # No interpretar valores como 'NA' como NaN
            na_values=[],  # No definir valores como NaN
            dtype={'cmp_code': str}  # Forzar la columna 'cmp_code' a tipo string
        )

        # Obtener el nombre del archivo sin ruta ni extensión
        nombre_archivo = archivo.split('/')[-1].replace('.csv', '')

        # Insertar la columna 'programa' como la primera columna
        df.insert(0, 'programa', nombre_archivo)

        # Agregar el DataFrame a la lista
        dataframes.append(df)
    except Exception as e:
        print(f"Error al leer {archivo}: {e}")

# Verificar si hay DataFrames para concatenar
if dataframes:
    df_programas_Chile = pd.concat(dataframes, ignore_index=True)
    print("DataFrame final:")
    print(df_programas_Chile.head())
else:
    print("No hay DataFrames para concatenar.")
# Out:
# Archivos encontrados: ['./data/Annotated_Chile/155021_200912.csv', './data/Annotated_Chile/155061_199312.csv', './data/Annotated_Chile/155601_200512.csv', './data/Annotated_Chile/155026_201711.csv', './data/Annotated_Chile/155980_201711.csv', './data/Annotated_Chile/155027_202111.csv', './data/Annotated_Chile/155620_198912.csv', './data/Annotated_Chile/155061_198912.csv', './data/Annotated_Chile/155501_201711.csv', './data/Annotated_Chile/155023_200912.csv', './data/Annotated_Chile/155201_201711.csv', './data/Annotated_Chile/155021_201311.csv', './data/Annotated_Chile/155021_199912.csv', './data/Annotated_Chile/155024_201311.csv', './data/Annotated_Chile/155021_201711.csv', './data/Annotated_Chile/155025_200512.csv', './data/Annotated_Chile/155061_202111.csv', './data/Annotated_Chile/155062_202111.csv', './data/Annotated_Chile/155061_200912.csv', './data/Annotated_Chile/155021_199312.csv', './data/Annotated_Chile/155025_200912.csv', './data/Annotated_Chile/155201_202111.csv', './data/Annotated_Chile/155021_198912.csv', './data/Annotated_Chile/155061_199912.csv', './data/Annotated_Chile/155061_201311.csv', './data/Annotated_Chile/155061_201711.csv', './data/Annotated_Chile/155401_202111.csv', './data/Annotated_Chile/155021_200512.csv', './data/Annotated_Chile/155602_200512.csv', './data/Annotated_Chile/155030_202111.csv']
# Leyendo archivo: ./data/Annotated_Chile/155021_200912.csv
# Leyendo archivo: ./data/Annotated_Chile/155061_199312.csv
# Leyendo archivo: ./data/Annotated_Chile/155601_200512.csv
# Leyendo archivo: ./data/Annotated_Chile/155026_201711.csv
# Leyendo archivo: ./data/Annotated_Chile/155980_201711.csv
# Leyendo archivo: ./data/Annotated_Chile/155027_202111.csv
# Leyendo archivo: ./data/Annotated_Chile/155620_198912.csv
# Leyendo archivo: ./data/Annotated_Chile/155061_198912.csv
# Leyendo archivo: ./data/Annotated_Chile/155501_201711.csv
# Leyendo archivo: ./data/Annotated_Chile/155023_200912.csv
# Leyendo archivo: ./data/Annotated_Chile/155201_201711.csv
# Leyendo archivo: ./data/Annotated_Chile/155021_201311.csv
# Leyendo archivo: ./data/Annotated_Chile/155021_199912.csv
# Leyendo archivo: ./data/Annotated_Chile/155024_201311.csv
# Leyendo archivo: ./data/Annotated_Chile/155021_201711.csv
# Leyendo archivo: ./data/Annotated_Chile/155025_200512.csv
# Leyendo archivo: ./data/Annotated_Chile/155061_202111.csv
# Leyendo archivo: ./data/Annotated_Chile/155062_202111.csv
# Leyendo archivo: ./data/Annotated_Chile/155061_200912.csv
# Leyendo archivo: ./data/Annotated_Chile/155021_199312.csv
# Leyendo archivo: ./data/Annotated_Chile/155025_200912.csv
# Leyendo archivo: ./data/Annotated_Chile/155201_202111.csv
# Leyendo archivo: ./data/Annotated_Chile/155021_198912.csv
# Leyendo archivo: ./data/Annotated_Chile/155061_199912.csv
# Leyendo archivo: ./data/Annotated_Chile/155061_201311.csv
# Leyendo archivo: ./data/Annotated_Chile/155061_201711.csv
# Leyendo archivo: ./data/Annotated_Chile/155401_202111.csv
# Leyendo archivo: ./data/Annotated_Chile/155021_200512.csv
# Leyendo archivo: ./data/Annotated_Chile/155602_200512.csv
# Leyendo archivo: ./data/Annotated_Chile/155030_202111.csv
# DataFrame final:
#         programa                                              frase  \
# 0  155021_200912  La campaña presidencial es una buena oportunid...
# 1  155021_200912                              Y así lo hemos hecho.
# 2  155021_200912    Hemos vuelto a recorrer el país de norte a sur.
# 3  155021_200912  Mis equipos de trabajo han recogido las inquie...
# 4  155021_200912  Hemos recopilado historias de vida de miles de...
#
#                                            frase_eng cmp_code eu_code
# 0  The presidential campaign is a good opportunit...    305.1      NA
# 1                                    And so we have.    305.1      NA
# 2  We have again toured the country from north to...    305.1      NA
# 3  My work teams have gathered the concerns of pe...    305.1      NA
# 4  We have collected life stories of thousands of...    305.1      NA

# %% [markdown]
# ### Preproceso a 'df_programas_Chile'
# * Buscamos valores 'NaN', o Missing values, en la columna 'cmp_code' que es la que contiene los nombres de las etiquetas
# * Eliminamos la columna 'eu_code' que no será utilizada

# %%
df_programas_Chile
# Out:
#             programa                                              frase  \
# 0      155021_200912  La campaña presidencial es una buena oportunid...
# 1      155021_200912                              Y así lo hemos hecho.
# 2      155021_200912    Hemos vuelto a recorrer el país de norte a sur.
# 3      155021_200912  Mis equipos de trabajo han recogido las inquie...
# 4      155021_200912  Hemos recopilado historias de vida de miles de...
# ...              ...                                                ...
# 56935  155030_202111  Participaremos de modo incidente de organizaci...
# 56936  155030_202111  5.4.5.Impulsaremos que la construcción de los ...
# 56937  155030_202111  Propiciaremos que se desarrolle el carnet de i...
# 56938  155030_202111  Propiciaremos que el Ministerio Público cuente...
# 56939  155030_202111  Impulsaremos la creación de un Programa de Mem...
#
#                                                frase_eng cmp_code eu_code
# 0      The presidential campaign is a good opportunit...    305.1      NA
# 1                                        And so we have.    305.1      NA
# 2      We have again toured the country from north to...    305.1      NA
# 3      My work teams have gathered the concerns of pe...    305.1      NA
# 4      We have collected life stories of thousands of...    305.1      NA
# ...                                                  ...      ...     ...
# 56935  We will participate incidentally with women's ...      503      NA
# 56936  5.4.5.We will promote the incorporation of gen...        H      NA
# 56937  We will promote the development of the gender-...      604      NA
# 56938  We will promote that the Public Prosecutor's O...    605.1      NA
# 56939  We will promote the creation of a Program of M...    201.2      NA
#
# [56940 rows x 5 columns]

# %% [markdown]
# #### Eliminamos la columna 'eu_code'. No la usaremos

# %%
df_programas_Chile = df_programas_Chile.drop(columns=['eu_code'])
df_programas_Chile.head()
# Out:
#         programa                                              frase  \
# 0  155021_200912  La campaña presidencial es una buena oportunid...
# 1  155021_200912                              Y así lo hemos hecho.
# 2  155021_200912    Hemos vuelto a recorrer el país de norte a sur.
# 3  155021_200912  Mis equipos de trabajo han recogido las inquie...
# 4  155021_200912  Hemos recopilado historias de vida de miles de...
#
#                                            frase_eng cmp_code
# 0  The presidential campaign is a good opportunit...    305.1
# 1                                    And so we have.    305.1
# 2  We have again toured the country from north to...    305.1
# 3  My work teams have gathered the concerns of pe...    305.1
# 4  We have collected life stories of thousands of...    305.1

# %% [markdown]
# ##### Revisamos la existencia de valores 'no string' que aún puedan quedar en 'cmp_code'

# %%
# Count the occurrences of non-string values in the 'cmp_code' column
non_string_count = df_programas_Chile['cmp_code'].apply(lambda x: not isinstance(x, str)).sum()

print(f"Number of non-string values in 'cmp_code': {non_string_count}")
# Out:
# Number of non-string values in 'cmp_code': 0

# %% [markdown]
# ##### Revisamos qué valores únicos quedan en 'cmp_code' para eliminar cualquier valor que no parezca un nombre de alguna de las variables

# %%
unique_cmp_code_values = df_programas_Chile['cmp_code'].unique()
unique_cmp_code_count = len(unique_cmp_code_values)

print(f"Unique values in 'cmp_code': {unique_cmp_code_values}")
print(f"Number of unique values in 'cmp_code': {unique_cmp_code_count}")
# Out:
# Unique values in 'cmp_code': ['305.1' '204' 'NA' '202.1' '303' '304' '301' '502' '305.6' '201.2'
#  '606.1' '107' '202.4' '607.3' '503' '202.3' '106' '108' '104' '105' '410'
#  '416.2' '701' '706' '506' '403' '402' '501' '414' '411' '703.1' '413'
#  '504' '605.1' '605.2' '705' '505' '201.1' '305.4' '603' '203' '401' '405'
#  '407' '109' '102' '305.2' '604' '704' '404' '101' '408' '606.2' 'H'
#  '305.5' '602.1' '607.1' '415' '601.1' '103.1' '416.1' '607.2' '412' '409'
#  '202.2' '602.2' '000' '702' '305.3' '103.2' '601.2' '406' '302' '110'
#  '608.3' '507' '608.1' '608.2' '703.2']
# Number of unique values in 'cmp_code': 79

# %% [markdown]
# ##### Identificamos los registros en que 'cmp_code' == 'H' ó 'NA'. Dejaremos las ocurrencias de 'cmp_code' == '000'.

# %%
# Filter rows where cmp_code is 'NA' or 'H'
filtered_rows = df_programas_Chile[(df_programas_Chile['cmp_code'] == 'NA') | (df_programas_Chile['cmp_code'] == 'H')]

# Print the desired columns
for index, row in filtered_rows.iterrows():
    print(f"Row: {index}, Programa: {row['programa']}, Frase: {row['frase']}, CMP Code: {row['cmp_code']}")
# Out:
# Row: 67, Programa: 155021_200912, Frase: 1)  Impulsando una mejor democracia y un mejor Estado, CMP Code: NA
# Row: 90, Programa: 155021_200912, Frase: HACIA UNA CONSTITUCIÓN DE TODOS, CMP Code: NA
# Row: 107, Programa: 155021_200912, Frase: HACIA LA DIGNIFICACIÓN DE LA POLÍTICA Y EL SERVICIO PÚBLICO, CMP Code: NA
# Row: 138, Programa: 155021_200912, Frase: HACIA UN PAÍS DESCENTRALIZADO Y CON GESTIÓN LOCAL, CMP Code: NA
# Row: 155, Programa: 155021_200912, Frase: HACIA UNA REFORMA DEL ESTADO PARA FORTALECER EL ESTADO, CMP Code: NA
# Row: 165, Programa: 155021_200912, Frase: HACIA MEJORES POLÍTICAS PÚBLICAS, CMP Code: NA
# Row: 178, Programa: 155021_200912, Frase: HACIA UNA CULTURA DEL DIÁLOGO SOCIAL, CMP Code: NA
# Row: 190, Programa: 155021_200912, Frase: HACIA UN PAÍS CON MEMORIA Y VERDAD, CMP Code: NA
# Row: 208, Programa: 155021_200912, Frase: HACIA UN PAÍS DE VOLUNTARIOS PÚBLICOS, CMP Code: NA
# Row: 224, Programa: 155021_200912, Frase: HACIA UNA MAYOR INTEGRACIÓN CON MUNDO MULTILATERAL, CMP Code: NA
# Row: 237, Programa: 155021_200912, Frase: 2)  Impulsando una nueva estructura económica, CMP Code: NA
# Row: 257, Programa: 155021_200912, Frase: HACIA UNA REFORMA LABORAL POR MÁS EMPLEO Y TRABAJO DECENTE, CMP Code: NA
# Row: 291, Programa: 155021_200912, Frase: HACIA UNA EDUCACIÓN DEMOCRÁTICA, INCLUSIVA Y DE EXCELENCIA, CMP Code: NA
# Row: 350, Programa: 155021_200912, Frase: HACIA UN NUEVO ROL DEL ESTADO PARA EL CRECIMIENTO Y EL DESARROLLO, CMP Code: NA
# Row: 384, Programa: 155021_200912, Frase: HACIA UNA ECONOMÍA VERDE, CMP Code: NA
# Row: 408, Programa: 155021_200912, Frase: 3) Impulsando el crecimiento y el desarrollo HACIA DELANTE CON POLÍTICAS MACROECONÓMICAS ESTABILIZADORAS, CMP Code: NA
# Row: 419, Programa: 155021_200912, Frase: HACIA UN PAÍS CON MÁS ENERGÍA Y MAYOR SEGURIDAD ENERGÉTICA, CMP Code: NA
# Row: 450, Programa: 155021_200912, Frase: HACIA UN PAÍS CON UNA POLÍTICA DE AGUAS Y DE CUENCAS, CMP Code: NA
# Row: 462, Programa: 155021_200912, Frase: HACIA UN NUEVO AVANCE EN INFRAESTRUCTURA Y CONECTIVIDAD, CMP Code: NA
# Row: 513, Programa: 155021_200912, Frase: HACIA UN PAÍS CON MÁS DESARROLLO PRODUCTIVO, CMP Code: NA
# Row: 519, Programa: 155021_200912, Frase: Para los sectores agrícola, forestal y sus industrias, CMP Code: NA
# Row: 558, Programa: 155021_200912, Frase: Para el sector turismo, CMP Code: NA
# Row: 571, Programa: 155021_200912, Frase: Para los sectores pesca y acuicultura, CMP Code: NA
# Row: 597, Programa: 155021_200912, Frase: Para el sector minero y su industria, CMP Code: NA
# Row: 609, Programa: 155021_200912, Frase: Para el sector financiero, CMP Code: NA
# Row: 632, Programa: 155021_200912, Frase: Para el sector telecomunicaciones, CMP Code: NA
# Row: 649, Programa: 155021_200912, Frase: 4) Impulsando una ciudad para la calidad de vida, CMP Code: NA
# Row: 660, Programa: 155021_200912, Frase: HACIA UNA NUEVA POLÍTICA DE CIUDAD, CMP Code: NA
# Row: 679, Programa: 155021_200912, Frase: También debemos ocuparnos de la regeneración de barrios., CMP Code: NA
# Row: 689, Programa: 155021_200912, Frase: HACIA MEJORES VIVIENDAS Y MEJORES BARRIOS, CMP Code: NA
# Row: 710, Programa: 155021_200912, Frase: HACIA UNA VIDA CON DEPORTE, CMP Code: NA
# Row: 731, Programa: 155021_200912, Frase: HACIA UNA CIUDADANÍA CON CULTURA, CMP Code: NA
# Row: 769, Programa: 155021_200912, Frase: 5)  Impulsando un país integrador y sin discriminación, CMP Code: NA
# Row: 786, Programa: 155021_200912, Frase: HACIA MÁS PARTICIPACIÓN, PROTECCIÓN Y RECONOCIMIENTO A LA MUJER, CMP Code: NA
# Row: 815, Programa: 155021_200912, Frase: HACIA UNA PLENA INCORPORACIÓN DE LOS DISCAPACITADOS A LA SOCIEDAD CHILENA, CMP Code: NA
# Row: 839, Programa: 155021_200912, Frase: HACIA UN PAÍS QUE INTEGRA Y RESPETA A SUS PUEBLOS INDÍGENAS, CMP Code: NA
# Row: 875, Programa: 155021_200912, Frase: HACIA UN PAÍS SIN DISCRIMINACIÓN A LAS MINORÍAS SEXUALES, CMP Code: NA
# Row: 888, Programa: 155021_200912, Frase: HACIA UN PAÍS CON MAYOR PROTECCIÓN A LA LIBERTAD DE CULTO, CMP Code: NA
# Row: 912, Programa: 155021_200912, Frase: 6) Impulsando la Protección Social y Extendiéndola a la Clase Media, CMP Code: NA
# Row: 925, Programa: 155021_200912, Frase: HACIA MÁS PROTECCIÓN PARA LA FAMILIA Y MÁS CUIDADO DE LA INFANCIA, CMP Code: NA
# Row: 963, Programa: 155021_200912, Frase: HACIA MÁS AVANCES PARA LOS ADULTOS MAYORES, CMP Code: NA
# Row: 971, Programa: 155021_200912, Frase: HACIA UNA SEGURIDAD CIUDADANA CON PAZ SOCIAL, CMP Code: NA
# Row: 995, Programa: 155021_200912, Frase: HACIA ADELANTE CON LA SALUD, CMP Code: NA
# Row: 1059, Programa: 155061_199312, Frase: 11 PROPUESTAS CENTRALES DEL PROGRAMA PE GOBIERNO DE ARTURO ALESSANDRI BESADemocracia estable y moderna, CMP Code: NA
# Row: 1062, Programa: 155061_199312, Frase: 1,1) Estabilidad institucional, CMP Code: NA
# Row: 1074, Programa: 155061_199312, Frase: 1,3) Más Información y poder de decisión para las personas., CMP Code: NA
# Row: 1085, Programa: 155061_199312, Frase: 1,3a) Menos burocracia, CMP Code: NA
# Row: 1090, Programa: 155061_199312, Frase: 1,3b) Descentralizar, regionalizar y municipalizar, CMP Code: NA
# Row: 1099, Programa: 155061_199312, Frase: 1,3d) Venta de las empresas del Estado., CMP Code: NA
# Row: 1102, Programa: 155061_199312, Frase: 1,4) Una política de defensa al servicio de los intereses permanentes del país., CMP Code: NA
# Row: 1122, Programa: 155061_199312, Frase: 1,5) Chile abierto al mundo: Modernización de las relaciones internacionales., CMP Code: NA
# Row: 1138, Programa: 155061_199312, Frase: Orientaciones de la Política Exterior:, CMP Code: NA
# Row: 1161, Programa: 155061_199312, Frase: 1,6 Reconciliación real: Superar las heridas del pasado mirando hacia el futuro: "Ley Aylwin"., CMP Code: NA
# Row: 1167, Programa: 155061_199312, Frase: 2 Desarrollar una sociedad sana y fuerte, CMP Code: NA
# Row: 1183, Programa: 155061_199312, Frase: 2,2 Políticas orientadas a la mujer, CMP Code: NA
# Row: 1188, Programa: 155061_199312, Frase: 2,2) Igualdad de derechos, CMP Code: NA
# Row: 1197, Programa: 155061_199312, Frase: 2,2c) La mujer y el Mundo laboral, CMP Code: NA
# Row: 1201, Programa: 155061_199312, Frase: 2,3) Políticas orientadas a la juventud, CMP Code: NA
# Row: 1207, Programa: 155061_199312, Frase: 2,3a) Más oportunidades de trabajo: remover los obstáculos al progreso de los jóvenes:, CMP Code: NA
# Row: 1220, Programa: 155061_199312, Frase: 2. 3b) Agresiones a la juventud:, CMP Code: NA
# Row: 1224, Programa: 155061_199312, Frase: 2,3c) Sentido de la responsabilidad personal:, CMP Code: NA
# Row: 1231, Programa: 155061_199312, Frase: 2,3d) Servicio Militar, CMP Code: NA
# Row: 1237, Programa: 155061_199312, Frase: 3) Garantizar la seguridad necesaria a todos los chilenos para vivir en paz, CMP Code: NA
# Row: 1242, Programa: 155061_199312, Frase: 3,1) Causas del clima de inseguridad en que viven los chilenos:, CMP Code: NA
# Row: 1251, Programa: 155061_199312, Frase: 3,2) Propuestas concretas para combatir la delincuencia y el extremismo, CMP Code: NA
# Row: 1272, Programa: 155061_199312, Frase: 3,3) Justicia eficiente, CMP Code: NA
# Row: 1291, Programa: 155061_199312, Frase: 4) Una economía abierta al mundo que asegure un crecimiento alto y sostenido4,1) Reafirmación de las bases de una economía social de mercado., CMP Code: NA
# Row: 1300, Programa: 155061_199312, Frase: 4,2) Contención de la Inflación., CMP Code: NA
# Row: 1310, Programa: 155061_199312, Frase: 4, 3) Nuevo impulso a las exportaciones, CMP Code: NA
# Row: 1320, Programa: 155061_199312, Frase: 4,4) Vender empresas del Estado para invertir en las personas y hacer de Chile un país de propietarios4,4) Principales criterios de venta, CMP Code: NA
# Row: 1343, Programa: 155061_199312, Frase: 4, 4b) Para qué vender empresas estatales:, CMP Code: NA
# Row: 1350, Programa: 155061_199312, Frase: 4, 4c) Capitalismo popular, laboral y regional, CMP Code: NA
# Row: 1354, Programa: 155061_199312, Frase: 4,5) Promover el Ahorro a través de un Rediseño Tributario., CMP Code: NA
# Row: 1360, Programa: 155061_199312, Frase: 4,6) Infraestructura adecuada para el desarrollo, CMP Code: NA
# Row: 1364, Programa: 155061_199312, Frase: 5) Políticas Sociales Justas y Eficientes5,1) Definición de una política social moderna y eficiente, CMP Code: NA
# Row: 1371, Programa: 155061_199312, Frase: 5,2) Propuestas para superar la extrema pobreza, CMP Code: NA
# Row: 1384, Programa: 155061_199312, Frase: 5,3) Estímulo al espíritu de emprender: mayor apoyo al microempresario, CMP Code: NA
# Row: 1399, Programa: 155061_199312, Frase: 6) Mejorar la calidad de vida cotidiana de los chilenos, CMP Code: NA
# Row: 1404, Programa: 155061_199312, Frase: 6,1) Una política ambiental al servicio del hombre:, CMP Code: NA
# Row: 1420, Programa: 155061_199312, Frase: 6,2) Cultura, CMP Code: NA
# Row: 1434, Programa: 155061_199312, Frase: 6,3) Modernizar la Ciudad, CMP Code: NA
# Row: 1440, Programa: 155061_199312, Frase: 6,4) Deporte y Recreación:, CMP Code: NA
# Row: 1448, Programa: 155061_199312, Frase: III Propuestas Sectoriales del Programa de Don Arturo Alessandri, CMP Code: NA
# Row: 1474, Programa: 155061_199312, Frase: 2) Salud para todos los chilenosDiagnóstico: Promesas y no hechos., CMP Code: NA
# Row: 1486, Programa: 155061_199312, Frase: II) Proposiciones: Salud para todos los chilenos, CMP Code: NA
# Row: 1504, Programa: 155061_199312, Frase: 3) Por una Vivienda Dignal) Diagnóstico: Se requieren perfeccionamientos, CMP Code: NA
# Row: 1516, Programa: 155061_199312, Frase: II) Proposiciones: Más Viviendas y Mayor Transparencia de la Gestión Pública, CMP Code: NA
# Row: 1526, Programa: 155061_199312, Frase: 4) Justicia Eficientel) Diagnóstico: Una Modernización Postergada, CMP Code: NA
# Row: 1549, Programa: 155061_199312, Frase: II) Proposiciones: Una Justicia eficiente, CMP Code: NA
# Row: 1563, Programa: 155061_199312, Frase: 5) Relaciones Exteriores para el Siglo XXIl) Diagnóstico: Obsolescencia en la política y la organización, CMP Code: NA
# Row: 1581, Programa: 155061_199312, Frase: II) Proposiciones: Modernización de la Cancillería, CMP Code: NA
# Row: 1619, Programa: 155061_199312, Frase: 6) Mayores Oportunidades de Trabajo: Mayor Flexibilidadl) Diagnóstico: Rigideces inconvenientes, CMP Code: NA
# Row: 1632, Programa: 155061_199312, Frase: II) Proposiciones Mayor flexibilidad para crear más y mejores trabajos, CMP Code: NA
# Row: 1659, Programa: 155061_199312, Frase: 7) Previsión: Perfeccionando un Sistema ExitosoDiagnóstico: Demagogia Previsional, CMP Code: NA
# Row: 1671, Programa: 155061_199312, Frase: II) Proposiciones: Perfeccionando un Sistema Exitoso., CMP Code: NA
# Row: 56936, Programa: 155030_202111, Frase: 5.4.5.Impulsaremos que la construcción de los datos nacionales incorpore las variables identidad y expresión de género, CMP Code: H

# %% [markdown]
# ##### Vamos a eliminar los registros con 'cmp_code' == 'NA' ó 'H'. Los '000' los dejaremos porque pueden ser útiles después.

# %%
# Count the number of rows to be removed
rows_to_remove = df_programas_Chile[(df_programas_Chile['cmp_code'] == 'NA') | (df_programas_Chile['cmp_code'] == 'H')].shape[0]

# Remove the rows
df_programas_Chile = df_programas_Chile[~((df_programas_Chile['cmp_code'] == 'NA') | (df_programas_Chile['cmp_code'] == 'H'))]

# Print the number of rows removed
print(f"Number of rows removed: {rows_to_remove}")

# Print the final number of rows
print(f"Final number of rows: {df_programas_Chile.shape[0]}")
# Out:
# Number of rows removed: 4095
# Final number of rows: 52845

# %% [markdown]
# ##### Reemplazamos los '.' en 'cmp_code' por un '_' para consistencia con el dataset del manifesto project

# %%
# Replace '.' with '_' in the 'cmp_code' column
df_programas_Chile['cmp_code'] = df_programas_Chile['cmp_code'].str.replace('.', '_', regex=False)

# Display the first few rows to verify the changes
df_programas_Chile.head()
# Out:
#         programa                                              frase  \
# 0  155021_200912  La campaña presidencial es una buena oportunid...
# 1  155021_200912                              Y así lo hemos hecho.
# 2  155021_200912    Hemos vuelto a recorrer el país de norte a sur.
# 3  155021_200912  Mis equipos de trabajo han recogido las inquie...
# 4  155021_200912  Hemos recopilado historias de vida de miles de...
#
#                                            frase_eng cmp_code
# 0  The presidential campaign is a good opportunit...    305_1
# 1                                    And so we have.    305_1
# 2  We have again toured the country from north to...    305_1
# 3  My work teams have gathered the concerns of pe...    305_1
# 4  We have collected life stories of thousands of...    305_1

# %% [markdown]
# ##### Exportamos a un archivo excel

# %%
# Export df_programas_Chile to an Excel file
output_file_path = 'df_programas_Chile.xlsx'
df_programas_Chile.to_excel(output_file_path, index=False)
print(f"DataFrame exported to {output_file_path}")
# Out:
# DataFrame exported to df_programas_Chile.xlsx

# %% [markdown]
# ##### Aseguramos que todos los valores en 'cmp_code' corresponde a nombres válidos de variables en el dataset de manifesto project. Estas variables están en el archivo 'Analytical_Data'

# %%
# cargar Analytical_Data
df_AD = pd.read_excel('data/Analytical_Data.xlsx')
df_AD.head()
# Out:
#     Dominio      Nombre_Dominio Variable_per  \
# 0  Domain_1  External Relations       per101
# 1  Domain_1  External Relations       per102
# 2  Domain_1  External Relations       per103
# 3  Domain_1  External Relations       per104
# 4  Domain_1  External Relations       per105
#
#                            Detalle_Dominio
# 0  Foreign Special Relationships: Positive
# 1  Foreign Special Relationships: Negative
# 2                         Anti-Imperialism
# 3                       Military: Positive
# 4                       Military: Negative

# %%
# Iterar sobre los valores únicos de 'cmp_code' en 'df_programas_Chile'
for cmp_code in unique_cmp_code_values:
    # Anteponer 'per' al valor de 'cmp_code'
    per_code = f'per{cmp_code}'
    
    # Buscar el valor en la columna 'Variable_per' de 'df_AD'
    if per_code not in df_AD['Variable_per'].values:
        # Filtrar las filas correspondientes en 'df_programas_Chile'
        filtered_rows = df_programas_Chile[df_programas_Chile['cmp_code'] == cmp_code]
        
        # Imprimir la línea, programa y cmp_code
        for index, row in filtered_rows.iterrows():
            print(f"Línea: {index}, Programa: {row['programa']}, CMP Code: {row['cmp_code']}")
# Out:
# Línea: 6989, Programa: 155026_201711, CMP Code: 000
# Línea: 7012, Programa: 155026_201711, CMP Code: 000
# Línea: 7036, Programa: 155026_201711, CMP Code: 000
# Línea: 7085, Programa: 155980_201711, CMP Code: 000
# Línea: 7086, Programa: 155980_201711, CMP Code: 000
# Línea: 7547, Programa: 155980_201711, CMP Code: 000
# Línea: 7806, Programa: 155980_201711, CMP Code: 000
# Línea: 9241, Programa: 155027_202111, CMP Code: 000
# Línea: 10803, Programa: 155027_202111, CMP Code: 000
# Línea: 16155, Programa: 155201_201711, CMP Code: 000
# Línea: 28559, Programa: 155061_202111, CMP Code: 000
# Línea: 28560, Programa: 155061_202111, CMP Code: 000
# Línea: 28561, Programa: 155061_202111, CMP Code: 000
# Línea: 28562, Programa: 155061_202111, CMP Code: 000
# Línea: 28564, Programa: 155061_202111, CMP Code: 000
# Línea: 28565, Programa: 155061_202111, CMP Code: 000
# Línea: 28571, Programa: 155061_202111, CMP Code: 000
# Línea: 28727, Programa: 155061_202111, CMP Code: 000
# Línea: 28728, Programa: 155061_202111, CMP Code: 000
# Línea: 29071, Programa: 155061_202111, CMP Code: 000
# Línea: 29117, Programa: 155061_202111, CMP Code: 000
# Línea: 29124, Programa: 155061_202111, CMP Code: 000
# Línea: 42511, Programa: 155021_198912, CMP Code: 000
# Línea: 46440, Programa: 155061_201711, CMP Code: 000
# Línea: 46454, Programa: 155061_201711, CMP Code: 000
# Línea: 46526, Programa: 155061_201711, CMP Code: 000
# Línea: 46607, Programa: 155061_201711, CMP Code: 000
# Línea: 47066, Programa: 155401_202111, CMP Code: 000
# Línea: 47953, Programa: 155401_202111, CMP Code: 000
# Línea: 48003, Programa: 155401_202111, CMP Code: 000
# Línea: 53356, Programa: 155030_202111, CMP Code: 000
# Línea: 53357, Programa: 155030_202111, CMP Code: 000
# Línea: 53559, Programa: 155030_202111, CMP Code: 000
# Línea: 55511, Programa: 155030_202111, CMP Code: 000

# %% [markdown]
# ##### Sólo encontró los registros con '000'; es decir, todos los demás son nombres válidos de variables.

# %%
df_programas_Chile
# Out:
#             programa                                              frase  \
# 0      155021_200912  La campaña presidencial es una buena oportunid...
# 1      155021_200912                              Y así lo hemos hecho.
# 2      155021_200912    Hemos vuelto a recorrer el país de norte a sur.
# 3      155021_200912  Mis equipos de trabajo han recogido las inquie...
# 4      155021_200912  Hemos recopilado historias de vida de miles de...
# ...              ...                                                ...
# 56934  155030_202111  Desarrollaremos la investigación de las necesi...
# 56935  155030_202111  Participaremos de modo incidente de organizaci...
# 56937  155030_202111  Propiciaremos que se desarrolle el carnet de i...
# 56938  155030_202111  Propiciaremos que el Ministerio Público cuente...
# 56939  155030_202111  Impulsaremos la creación de un Programa de Mem...
#
#                                                frase_eng cmp_code
# 0      The presidential campaign is a good opportunit...    305_1
# 1                                        And so we have.    305_1
# 2      We have again toured the country from north to...    305_1
# 3      My work teams have gathered the concerns of pe...    305_1
# 4      We have collected life stories of thousands of...    305_1
# ...                                                  ...      ...
# 56934  We will develop research on the needs of careg...      504
# 56935  We will participate incidentally with women's ...      503
# 56937  We will promote the development of the gender-...      604
# 56938  We will promote that the Public Prosecutor's O...    605_1
# 56939  We will promote the creation of a Program of M...    201_2
#
# [52845 rows x 4 columns]

# %% [markdown]
# ##### Revisión final de 'df_programas_Chile' buscando valores 'nan', 'NA', 'H', 'Missing values'

# %%
# Define the list of values to count
values_to_count = ['nan', 'NA', 'NAN', 'H', 'Missing values']

# Count the occurrences of each value in the 'cmp_code' column
occurrences = df_programas_Chile['cmp_code'].isin(values_to_count).sum()

print(f"Occurrences of specified values in 'cmp_code': {occurrences}")
# Out:
# Occurrences of specified values in 'cmp_code': 0

# %% [markdown]
# *   DF_ABSOLUTOS
# *   5.Duplicamos 'df_Manifesto_Project' en 'df_absolutos'
# *   6.xdc
# *   7.En 'df_absolutos' sólo dejar los registros de Chile y poner ceros en las variables 'per'
# *   8.En 'df_absolutos' agregar una columna 'num_frases'
# *   9.En 'df_programas_Chile' contar las frases de cada programa y registrarlo en 'df_absoluto'
# *   10.Poblar 'df_absolutos', multiplicando los valores 'per' de 'df' por 'num_frases'
# *   11.Elegir un feature vector conveniente
# *   12.Graficar con valores absolutos y comparar con gráficas hechas en base a % para el mismo feature vector
# *   13.Concluir

# %% [markdown]
# #### Creamos df_absolutos

# %% [markdown]
# #### Cargamos el dataset de Manifesto Project

# %%
file_path = "data/MPDataset_MPDS2024a.csv"
df_Manifesto_project = pd.read_csv(file_path)
df_Manifesto_project.shape
# Out:
# /var/folders/v8/d2xyhw9n7pb9rqd7k0d1xfsc0000gn/T/ipykernel_6180/2392630412.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Manifesto_project = pd.read_csv(file_path)
# (5151, 175)

# %%
df_absolutos = df_Manifesto_project.copy()

# %% [markdown]
# #### Dejamos sólo registros de Chile

# %%
# Delete all records where 'countryname' is not 'Chile'
df_absolutos = df_absolutos[df_absolutos['countryname'] == 'Chile']
df_absolutos.head()
# Out:
#       country countryname  oecdmember  eumember       edate    date   party  \
# 4895      155       Chile          10         0  14/12/1989  198912  155021
# 4896      155       Chile          10         0  14/12/1989  198912  155061
# 4897      155       Chile          10         0  14/12/1989  198912  155620
# 4898      155       Chile          10         0  11/12/1993  199312  155021
# 4899      155       Chile          10         0  11/12/1993  199312  155061
#
#                              partyname partyabbrev  parfam  ... per608_3  \
# 4895  Concert of Parties for Democracy         NaN      20  ...      0.0
# 4896            Democracy and Progress         NaN      60  ...      0.0
# 4897       Liberal-Socialists of Chile         NaN      60  ...      0.0
# 4898  Concert of Parties for Democracy         NaN      20  ...      0.0
# 4899        Union for Chile's Progress         NaN      60  ...      0.0
#
#       per703_1  per703_2    rile  planeco  markeco  welfare  intpeace  \
# 4895     2.165       0.0 -15.152    4.205    3.958   12.369     1.855
# 4896     1.171       0.0  21.405    0.167    8.863    7.692     1.672
# 4897     0.000       0.0  -3.968    3.968    6.349   29.365     0.000
# 4898     2.001       0.0 -10.493    5.368    3.758   13.860     0.537
# 4899     5.044       0.0  25.347    1.513   15.385    7.818     0.252
#
#       datasetversion  id_perm
# 4895           2024a   LS71MA
# 4896           2024a   SQXTCB
# 4897           2024a   2IDQNL
# 4898           2024a   6B4L5M
# 4899           2024a   X97LN2
#
# [5 rows x 175 columns]

# %%
df_absolutos.shape
# Out:
# (30, 175)

# %% [markdown]
# #### Debemos homologar el nombre del programa en ambos dataframe y validar que los pares partido_fecha existen en ambos dataframe

# %%
df_programas_Chile
# Out:
#             programa                                              frase  \
# 0      155021_200912  La campaña presidencial es una buena oportunid...
# 1      155021_200912                              Y así lo hemos hecho.
# 2      155021_200912    Hemos vuelto a recorrer el país de norte a sur.
# 3      155021_200912  Mis equipos de trabajo han recogido las inquie...
# 4      155021_200912  Hemos recopilado historias de vida de miles de...
# ...              ...                                                ...
# 56934  155030_202111  Desarrollaremos la investigación de las necesi...
# 56935  155030_202111  Participaremos de modo incidente de organizaci...
# 56937  155030_202111  Propiciaremos que se desarrolle el carnet de i...
# 56938  155030_202111  Propiciaremos que el Ministerio Público cuente...
# 56939  155030_202111  Impulsaremos la creación de un Programa de Mem...
#
#                                                frase_eng cmp_code
# 0      The presidential campaign is a good opportunit...    305_1
# 1                                        And so we have.    305_1
# 2      We have again toured the country from north to...    305_1
# 3      My work teams have gathered the concerns of pe...    305_1
# 4      We have collected life stories of thousands of...    305_1
# ...                                                  ...      ...
# 56934  We will develop research on the needs of careg...      504
# 56935  We will participate incidentally with women's ...      503
# 56937  We will promote the development of the gender-...      604
# 56938  We will promote that the Public Prosecutor's O...    605_1
# 56939  We will promote the creation of a Program of M...    201_2
#
# [52845 rows x 4 columns]

# %% [markdown]
# #### Aseguremos que para cada programa em 'df_programas_Chile' existe en 'df_absolutos' un registro con el mismo 'party'_'date'

# %%
# Extract unique values of 'programa' from 'df_programas_Chile'
unique_programas = df_programas_Chile['programa'].unique()

# Initialize a list to store warnings
warnings = []

# Iterate over unique values of 'programa'
for programa in unique_programas:
    # Extract the leftmost 6 characters and rightmost 6 characters
    left_6 = programa[:6]
    right_6 = programa[-6:]
    
    # Validate if 'party' and 'date' exist in 'df_absolutos'
    if not ((df_absolutos['party'] == int(left_6)) & (df_absolutos['date'] == int(right_6))).any():
        warnings.append(f"Warning: No matching row found for 'party' == {left_6} and 'date' == {right_6}")

# Print warnings if any
for warning in warnings:
    print(warning)

# %%
df_absolutos.head()
# Out:
#       country countryname  oecdmember  eumember       edate    date   party  \
# 4895      155       Chile          10         0  14/12/1989  198912  155021
# 4896      155       Chile          10         0  14/12/1989  198912  155061
# 4897      155       Chile          10         0  14/12/1989  198912  155620
# 4898      155       Chile          10         0  11/12/1993  199312  155021
# 4899      155       Chile          10         0  11/12/1993  199312  155061
#
#                              partyname partyabbrev  parfam  ... per608_3  \
# 4895  Concert of Parties for Democracy         NaN      20  ...      0.0
# 4896            Democracy and Progress         NaN      60  ...      0.0
# 4897       Liberal-Socialists of Chile         NaN      60  ...      0.0
# 4898  Concert of Parties for Democracy         NaN      20  ...      0.0
# 4899        Union for Chile's Progress         NaN      60  ...      0.0
#
#       per703_1  per703_2    rile  planeco  markeco  welfare  intpeace  \
# 4895     2.165       0.0 -15.152    4.205    3.958   12.369     1.855
# 4896     1.171       0.0  21.405    0.167    8.863    7.692     1.672
# 4897     0.000       0.0  -3.968    3.968    6.349   29.365     0.000
# 4898     2.001       0.0 -10.493    5.368    3.758   13.860     0.537
# 4899     5.044       0.0  25.347    1.513   15.385    7.818     0.252
#
#       datasetversion  id_perm
# 4895           2024a   LS71MA
# 4896           2024a   SQXTCB
# 4897           2024a   2IDQNL
# 4898           2024a   6B4L5M
# 4899           2024a   X97LN2
#
# [5 rows x 175 columns]

# %% [markdown]
# #### En 'df_absolutos', cada columna 'per' que representa una variable que nos interesa, la multiplicamos por la columna 'total'

# %%
# Create a list of column names that begin with 'per' and have a digit or an underscore in position 4
variables_per = [col for col in df_absolutos.columns if col.startswith('per') and (col[3].isdigit() or col[3] == '_')]

print(f"Total variables per: {len(variables_per)}")
# Out:
# Total variables per: 142

# %%
# Multiplicar cada columna en 'variables_per' por el valor en la columna 'total y dividir por 100'
for col in variables_per:
    df_absolutos[col] = (df_absolutos[col] * df_absolutos['total'] / 100).round(0).astype(int)
df_absolutos.head()
# Out:
#       country countryname  oecdmember  eumember       edate    date   party  \
# 4895      155       Chile          10         0  14/12/1989  198912  155021
# 4896      155       Chile          10         0  14/12/1989  198912  155061
# 4897      155       Chile          10         0  14/12/1989  198912  155620
# 4898      155       Chile          10         0  11/12/1993  199312  155021
# 4899      155       Chile          10         0  11/12/1993  199312  155061
#
#                              partyname partyabbrev  parfam  ... per608_3  \
# 4895  Concert of Parties for Democracy         NaN      20  ...        0
# 4896            Democracy and Progress         NaN      60  ...        0
# 4897       Liberal-Socialists of Chile         NaN      60  ...        0
# 4898  Concert of Parties for Democracy         NaN      20  ...        0
# 4899        Union for Chile's Progress         NaN      60  ...        0
#
#       per703_1  per703_2    rile  planeco  markeco  welfare  intpeace  \
# 4895        35         0 -15.152    4.205    3.958   12.369     1.855
# 4896         7         0  21.405    0.167    8.863    7.692     1.672
# 4897         0         0  -3.968    3.968    6.349   29.365     0.000
# 4898        41         0 -10.493    5.368    3.758   13.860     0.537
# 4899        40         0  25.347    1.513   15.385    7.818     0.252
#
#       datasetversion  id_perm
# 4895           2024a   LS71MA
# 4896           2024a   SQXTCB
# 4897           2024a   2IDQNL
# 4898           2024a   6B4L5M
# 4899           2024a   X97LN2
#
# [5 rows x 175 columns]

# %%
# Export df_absolutos to an Excel file
output_file_path = 'df_absolutos.xlsx'
df_absolutos.to_excel(output_file_path, index=False)
print(f"DataFrame exported to {output_file_path}")
# Out:
# DataFrame exported to df_absolutos.xlsx

# %% [markdown]
# #### Unificamos el nombre de S. Piñera

# %%
# Corrige nombre de Se
# Count the number of changes
count_changes = df_absolutos.loc[df_absolutos['candidatename'].notna() & df_absolutos['candidatename'].str.contains('Piñera'), 'candidatename'].count()

# Replace the values
df_absolutos.loc[df_absolutos['candidatename'].notna() & df_absolutos['candidatename'].str.contains('Piñera'), 'candidatename'] = 'Sebastián Piñera Echeñique'
print(f"Number of changes: {count_changes}")
# Out:
# Number of changes: 3

# %% [markdown]
# #### Agregamos el 'agno' de la elección

# %%
# Insert column 'agno' into the dataframe, of type int, to the right of column 'date'
df_absolutos.insert(df_absolutos.columns.get_loc('date') + 1, 'agno', df_absolutos['edate'].str[-4:].astype(int))

unique_agno_values = df_absolutos['agno'].unique()
unique_agno_values
# Out:
# /var/folders/v8/d2xyhw9n7pb9rqd7k0d1xfsc0000gn/T/ipykernel_6180/1274501083.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_absolutos.insert(df_absolutos.columns.get_loc('date') + 1, 'agno', df_absolutos['edate'].str[-4:].astype(int))
# array([1989, 1993, 1999, 2005, 2009, 2013, 2017, 2021])

# %% [markdown]
# #### Modifiquemos el nombre de 'df_resultados' y lo dejamos como 'df_absolutos_Chile'

# %%
df_absolutos_Chile = df_absolutos

# %% [markdown]
# #### Ordenamos por año y luego ponderamos por 'pervote'. Obtenemos 'df_absolutos_Chile_ponderado'

# %%
# Ordenemos por 'agno'
df_absolutos_Chile = df_absolutos_Chile.sort_values(by='agno')

# Group by column 'agno' and calculate the weighted average of each column in 'variables_per' using column 'presvote' as weights
df_absolutos_Chile_ponderados = df_absolutos_Chile.groupby('agno').apply(
    lambda x: pd.Series({col: np.average(x[col], weights=x['presvote']) for col in variables_per})
).reset_index()

# Display the results
df_absolutos_Chile_ponderados.head()
# Out:
#    agno     per101    per102  per103     per104     per105    per106  \
# 0  1989   3.934500  0.294000  3.3102  25.225800  13.019400  6.177600
# 1  1993   3.592548  0.296274  0.0000  13.259012   4.222357  3.814905
# 2  1999   0.513000  1.461000  0.0000  28.097000   3.591000  1.026000
# 3  2005  10.905300  0.000000  0.4860  25.757100  13.392600  7.196100
# 4  2009   0.062100  0.000000  1.9251  17.479400   5.491600  0.296000
#
#       per107    per108    per109  ...   per606_1   per606_2  per607_1  \
# 0  56.999400  12.76170  5.295600  ...  13.865100   4.413600    5.5170
# 1  57.297488  14.77825  0.296274  ...  36.371404   2.814905    0.0000
# 2  15.175000   3.51300  0.000000  ...  16.026000   0.000000    4.5130
# 3  46.265900  11.74800  9.791700  ...  17.225300  11.380800    3.6768
# 4  26.876300  11.66700  0.751100  ...   5.727500   0.000000    0.0000
#
#    per607_2   per607_3  per608_1  per608_2  per608_3   per703_1  per703_2
# 0  0.000000   2.206800       0.0       0.0       0.0  21.367500       0.0
# 1  1.407452   0.703726       0.0       0.0       0.0  40.703726       0.0
# 2  0.000000  11.130000       0.0       0.0       0.0  23.636000       0.0
# 3  0.919200  23.285700       0.0       0.0       0.0  16.192800       0.0
# 4  0.440600  36.324900       0.0       0.0       0.0  26.568400       0.0
#
# [5 rows x 143 columns]

# %%
# Export df_absolutos_Chile_ponderados to an Excel file
output_file_path = 'df_absolutos_Chile_ponderados.xlsx'
df_absolutos_Chile_ponderados.to_excel(output_file_path, index=False)
print(f"DataFrame exported to {output_file_path}")
# Out:
# DataFrame exported to df_absolutos_Chile_ponderados.xlsx

# %% [markdown]
# #### Cargamos 'df_porcentual_Chile_ponderado' para hacer un gráfico conjunto con 'df_absolutos_Chile_ponderados'

# %%
df_porcentual_Chile_ponderados = pd.read_excel('df_porcentual_Chile_ponderados.xlsx')
df_porcentual_Chile_ponderados.head()
# Out:
#    agno    per101    per102    per103    per104    per105    per106    per107  \
# 0  1989  0.367161  0.049098  0.204681  2.241851  0.898452  0.567973  4.764237
# 1  1993  0.289693  0.037331  0.000000  1.127951  0.206192  0.209040  3.254579
# 2  1999  0.056430  0.126620  0.000000  2.584547  0.393984  0.112347  1.348291
# 3  2005  0.501296  0.000000  0.108972  1.237788  0.586723  0.361019  2.251643
# 4  2009  0.005651  0.000000  0.174377  0.897141  0.376400  0.029600  1.546047
#
#      per108    per109  ...  per606_1  per606_2  per607_1  per607_2  per607_3  \
# 0  0.913344  0.420679  ...  0.981203  0.273091  0.340951  0.000000  0.136270
# 1  0.721319  0.037331  ...  1.866414  0.137227  0.000000  0.068965  0.034483
# 2  0.351827  0.000000  ...  1.588358  0.000000  0.449626  0.000000  1.152555
# 3  0.646983  0.425330  ...  1.451055  0.567666  0.134203  0.033551  1.563993
# 4  0.789124  0.050161  ...  0.631070  0.000000  0.000000  0.022030  2.946260
#
#    per608_1  per608_2  per608_3  per703_1  per703_2
# 0       0.0       0.0       0.0  1.538704       0.0
# 1       0.0       0.0       0.0  2.902561       0.0
# 2       0.0       0.0       0.0  2.163017       0.0
# 3       0.0       0.0       0.0  0.783858       0.0
# 4       0.0       0.0       0.0  2.101008       0.0
#
# [5 rows x 143 columns]

# %% [markdown]
# ## <p style="color:red">OJO: Cuando analizo valores ABSOLUTOS en Chile, NO necesito ponderar en cada elección. Puedo sumar directamente las menciones de los candidatos.</p>
# <p style="color:blue">Este texto es azul.</p>
# <p style="color:green">Este texto es verde.</p>

# %% [markdown]
# #### ANALICEMOS PUEBLOS ORIGINARIOS Y ENTENDAMOS DE DÓNDE PROVIENE EL PEAK DE 2013

# %% [markdown]
# #### Veamos las menciones absolutas en los discursos (usamos 'df_absolutos')

# %%
df_absolutos
# Out:
#       country countryname  oecdmember  eumember       edate    date  agno  \
# 4895      155       Chile          10         0  14/12/1989  198912  1989
# 4896      155       Chile          10         0  14/12/1989  198912  1989
# 4897      155       Chile          10         0  14/12/1989  198912  1989
# 4898      155       Chile          10         0  11/12/1993  199312  1993
# 4899      155       Chile          10         0  11/12/1993  199312  1993
# 4900      155       Chile          10         0  12/12/1999  199912  1999
# 4901      155       Chile          10         0  12/12/1999  199912  1999
# 4902      155       Chile          10         0  11/12/2005  200512  2005
# 4903      155       Chile          10         0  11/12/2005  200512  2005
# 4904      155       Chile          10         0  11/12/2005  200512  2005
df_abs_Chile_orginarios = df_absolutos_Chile_ponderados[['agno', col_1, col_2]].copy()
df_porcentual_Chile_orginarios = df_porcentual_Chile_ponderados[['agno', col_1, col_2]].copy()

# Add a new column 'Total' with the sum of columns in both datasets
df_abs_Chile_orginarios['Total'] = df_abs_Chile_orginarios[col_1] + df_abs_Chile_orginarios[col_2] #+ df_abs_Chile_orginarios[col_3]
df_porcentual_Chile_orginarios['Total'] = df_porcentual_Chile_orginarios[col_1] + df_porcentual_Chile_orginarios[col_2] #+ df_porcentual_Chile_orginarios[col_3]

# Create subplots (2 columns, 1 row) with shared x-axis
fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(14, 6))

# ----------------- Primer gráfico: valores absolutos y porcentuales -----------------

# Plot the absolute values on the left axis
ax1.plot(df_abs_Chile_orginarios['agno'], df_abs_Chile_orginarios[col_1], label=f"{col_1} (Absoluto)", color='b')  # Azul
ax1.plot(df_abs_Chile_orginarios['agno'], df_abs_Chile_orginarios[col_2], label=f"{col_2} (Absoluto)", color='g')  # Verde
# ax1.plot(df_abs_Chile_orden['agno'], df_abs_Chile_orden[col_3], label=f"{col_3} (Absoluto)", color='r')  # Rojo
# Cambié el color de la línea de Total Absoluto a un color distinto para evitar colisión
ax1.plot(df_abs_Chile_orginarios['agno'], df_abs_Chile_orginarios['Total'], label=f"Total\n(Absoluto)", color='black')  # Negro

ax1.set_xlabel('Año')
ax1.set_ylabel('Valores Absolutos')
ax1.set_title(f'PAÍS: CHILE - Valores Absolutos y Porcentuales\n{tema}')
ax1.grid(True)
ax1.legend(loc="upper left")

# Create a second y-axis for the porcentual values
ax2 = ax1.twinx()
ax2.plot(df_porcentual_Chile_orginarios['agno'], df_porcentual_Chile_orginarios[col_1], label=f"{col_1} (Porcentual)", linestyle='--', color='b')  # Azul
ax2.plot(df_porcentual_Chile_orginarios['agno'], df_porcentual_Chile_orginarios[col_2], label=f"{col_2} (Porcentual)", linestyle='--', color='g')  # Verde
#ax2.plot(df_porcentual_Chile_orden['agno'], df_porcentual_Chile_orden[col_3], label=f"{col_3} (Porcentual)", linestyle='--', color='r')  # Rojo
# Cambié el color de la línea de Total Porcentual a un color diferente
ax2.plot(df_porcentual_Chile_orginarios['agno'], df_porcentual_Chile_orginarios['Total'], label=f"Total\n(Porcentual)", linestyle='--', color='purple')  # Púrpura

ax2.set_ylabel('Valores Porcentuales')
ax2.legend(loc="upper right")

# ----------------- Segundo gráfico: sólo los Totales -----------------

# En el segundo gráfico, se usarán colores diferentes para los Totales (no necesariamente los mismos)
# Usar color diferente para el Total Absoluto y el Total Porcentual

# Plot the "Total" lines for both datasets in the second subplot
ax3.plot(df_abs_Chile_orginarios['agno'], df_abs_Chile_orginarios['Total'], label=f"Total\n(Absoluto)", color='orange')  # Naranja para total absoluto
ax3.set_xlabel('Año')
ax3.set_ylabel('Valores Absolutos')
ax3.grid(True)

# Create a second y-axis for the porcentual "Total" line
ax4 = ax3.twinx()
ax4.plot(df_porcentual_Chile_orginarios['agno'], df_porcentual_Chile_orginarios['Total'], label=f"Total\n(Porcentual)", color='brown')  # Marrón para total porcentual
ax4.set_ylabel('Valores Porcentuales')

# Set titles and legends for the second subplot
ax3.set_title(f'PAÍS: CHILE - Totales Absolutos y Porcentuales\n{tema}')
ax3.legend(loc="upper left")
ax4.legend(loc="upper right")

texto_md = """<div style="display: flex; justify-content: space-between;">
  <img src="../assets/per607_3.png" alt="" width="550"></div>
  <img src="../assets/per608_3.png" alt="" width="550">
</div>
"""
display(Markdown(texto_md))

# Show the plot
plt.tight_layout()  # Adjust layout to fit both plots
plt.show()
# Out:
# <div style="display: flex; justify-content: space-between;">
#   <img src="../assets/per607_3.png" alt="" width="550"></div>
#   <img src="../assets/per608_3.png" alt="" width="550">
# </div>

# %% [markdown]
# #### MEDIO AMBIENTE Y SOSTENIBILIDAD

# %%
# Define variables for the columns
tema = "MEDIO AMBIENTE Y SOSTENIBILIDAD"
col_1 = 'per501'
col_2 = 'per416_2'
# col_3 = 'per304'

# Select columns from df_absolutos_Chile_ponderados and df_porcentual_Chile_ponderados
df_abs_Chile_medio = df_absolutos_Chile_ponderados[['agno', col_1, col_2]].copy()
df_porcentual_Chile_medio = df_porcentual_Chile_ponderados[['agno', col_1, col_2]].copy()

# Add a new column 'Total' with the sum of columns in both datasets
df_abs_Chile_medio['Total'] = df_abs_Chile_medio[col_1] + df_abs_Chile_medio[col_2] #+ df_abs_Chile_orginarios[col_3]
df_porcentual_Chile_medio['Total'] = df_porcentual_Chile_medio[col_1] + df_porcentual_Chile_medio[col_2] #+ df_porcentual_Chile_orginarios[col_3]

# Create subplots (2 columns, 1 row) with shared x-axis
fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(14, 6))

# ----------------- Primer gráfico: valores absolutos y porcentuales -----------------

# Plot the absolute values on the left axis
ax1.plot(df_abs_Chile_medio['agno'], df_abs_Chile_medio[col_1], label=f"{col_1} (Absoluto)", color='b')  # Azul
ax1.plot(df_abs_Chile_medio['agno'], df_abs_Chile_medio[col_2], label=f"{col_2} (Absoluto)", color='g')  # Verde
# ax1.plot(df_abs_Chile_orden['agno'], df_abs_Chile_orden[col_3], label=f"{col_3} (Absoluto)", color='r')  # Rojo
# Cambié el color de la línea de Total Absoluto a un color distinto para evitar colisión
ax1.plot(df_abs_Chile_medio['agno'], df_abs_Chile_medio['Total'], label=f"Total\n(Absoluto)", color='black')  # Negro

ax1.set_xlabel('Año')
ax1.set_ylabel('Valores Absolutos')
ax1.set_title(f'PAÍS: CHILE - Valores Absolutos y Porcentuales\n{tema}')
ax1.grid(True)
ax1.legend(loc="upper left")

# Create a second y-axis for the porcentual values
ax2 = ax1.twinx()
ax2.plot(df_porcentual_Chile_medio['agno'], df_porcentual_Chile_medio[col_1], label=f"{col_1} (Porcentual)", linestyle='--', color='b')  # Azul
ax2.plot(df_porcentual_Chile_medio['agno'], df_porcentual_Chile_medio[col_2], label=f"{col_2} (Porcentual)", linestyle='--', color='g')  # Verde
#ax2.plot(df_porcentual_Chile_orden['agno'], df_porcentual_Chile_orden[col_3], label=f"{col_3} (Porcentual)", linestyle='--', color='r')  # Rojo
# Cambié el color de la línea de Total Porcentual a un color diferente
ax2.plot(df_porcentual_Chile_medio['agno'], df_porcentual_Chile_medio['Total'], label=f"Total\n(Porcentual)", linestyle='--', color='purple')  # Púrpura

ax2.set_ylabel('Valores Porcentuales')
ax2.legend(loc="upper right")

# ----------------- Segundo gráfico: sólo los Totales -----------------

# En el segundo gráfico, se usarán colores diferentes para los Totales (no necesariamente los mismos)
# Usar color diferente para el Total Absoluto y el Total Porcentual

# Plot the "Total" lines for both datasets in the second subplot
ax3.plot(df_abs_Chile_medio['agno'], df_abs_Chile_medio['Total'], label=f"Total\n(Absoluto)", color='orange')  # Naranja para total absoluto
ax3.set_xlabel('Año')
ax3.set_ylabel('Valores Absolutos')
ax3.grid(True)

# Create a second y-axis for the porcentual "Total" line
ax4 = ax3.twinx()
ax4.plot(df_porcentual_Chile_medio['agno'], df_porcentual_Chile_medio['Total'], label=f"Total\n(Porcentual)", color='brown')  # Marrón para total porcentual
ax4.set_ylabel('Valores Porcentuales')

# Set titles and legends for the second subplot
ax3.set_title(f'PAÍS: CHILE - Totales Absolutos y Porcentuales\n{tema}')
ax3.legend(loc="upper left")
ax4.legend(loc="upper right")

texto_md = """<div style="display: flex; justify-content: space-between;">
  <img src="../assets/per501.png" alt="" width="550"></div>
  <img src="../assets/per416_2.png" alt="" width="550">
</div>
"""
display(Markdown(texto_md))

# Show the plot
plt.tight_layout()  # Adjust layout to fit both plots
plt.show()
# Out:
# <div style="display: flex; justify-content: space-between;">
#   <img src="../assets/per501.png" alt="" width="550"></div>
#   <img src="../assets/per416_2.png" alt="" width="550">
# </div>

# %% [markdown]
# #### DERECHOS HUMANOS

# %%
# Define variables for the columns
tema = "DERECHOS HUMANOS"
col_1 = 'per201_1'
col_2 = 'per201_2'
# col_3 = 'per304'

# Select columns from df_absolutos_Chile_ponderados and df_porcentual_Chile_ponderados
df_abs_Chile_ddhh = df_absolutos_Chile_ponderados[['agno', col_1, col_2]].copy()
df_porcentual_Chile_ddhh = df_porcentual_Chile_ponderados[['agno', col_1, col_2]].copy()

# Add a new column 'Total' with the sum of columns in both datasets
df_abs_Chile_ddhh['Total'] = df_abs_Chile_ddhh[col_1] + df_abs_Chile_ddhh[col_2] #+ df_abs_Chile_orginarios[col_3]
df_porcentual_Chile_ddhh['Total'] = df_porcentual_Chile_ddhh[col_1] + df_porcentual_Chile_ddhh[col_2] #+ df_porcentual_Chile_orginarios[col_3]

# Create subplots (2 columns, 1 row) with shared x-axis
fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(14, 6))

# ----------------- Primer gráfico: valores absolutos y porcentuales -----------------

# Plot the absolute values on the left axis
ax1.plot(df_abs_Chile_ddhh['agno'], df_abs_Chile_ddhh[col_1], label=f"{col_1} (Absoluto)", color='b')  # Azul
ax1.plot(df_abs_Chile_ddhh['agno'], df_abs_Chile_ddhh[col_2], label=f"{col_2} (Absoluto)", color='g')  # Verde
# ax1.plot(df_abs_Chile_orden['agno'], df_abs_Chile_orden[col_3], label=f"{col_3} (Absoluto)", color='r')  # Rojo
# Cambié el color de la línea de Total Absoluto a un color distinto para evitar colisión
ax1.plot(df_abs_Chile_ddhh['agno'], df_abs_Chile_ddhh['Total'], label=f"Total\n(Absoluto)", color='black')  # Negro

ax1.set_xlabel('Año')
ax1.set_ylabel('Valores Absolutos')
ax1.set_title(f'PAÍS: CHILE - Valores Absolutos y Porcentuales\n{tema}')
ax1.grid(True)
ax1.legend(loc="upper left")

# Create a second y-axis for the porcentual values
ax2 = ax1.twinx()
ax2.plot(df_porcentual_Chile_ddhh['agno'], df_porcentual_Chile_ddhh[col_1], label=f"{col_1} (Porcentual)", linestyle='--', color='b')  # Azul
ax2.plot(df_porcentual_Chile_ddhh['agno'], df_porcentual_Chile_ddhh[col_2], label=f"{col_2} (Porcentual)", linestyle='--', color='g')  # Verde
#ax2.plot(df_porcentual_Chile_orden['agno'], df_porcentual_Chile_orden[col_3], label=f"{col_3} (Porcentual)", linestyle='--', color='r')  # Rojo
# Cambié el color de la línea de Total Porcentual a un color diferente
ax2.plot(df_porcentual_Chile_ddhh['agno'], df_porcentual_Chile_ddhh['Total'], label=f"Total\n(Porcentual)", linestyle='--', color='purple')  # Púrpura

ax2.set_ylabel('Valores Porcentuales')
ax2.legend(loc="upper right")

# ----------------- Segundo gráfico: sólo los Totales -----------------

# Plot the "Total" lines for both datasets in the second subplot
ax3.plot(df_abs_Chile_ddhh['agno'], df_abs_Chile_ddhh['Total'], label=f"Total\n(Absoluto)", color='orange')  # Naranja para total absoluto
ax3.set_xlabel('Año')
ax3.set_ylabel('Valores Absolutos')
ax3.grid(True)

# Create a second y-axis for the porcentual "Total" line
ax4 = ax3.twinx()
ax4.plot(df_porcentual_Chile_ddhh['agno'], df_porcentual_Chile_ddhh['Total'], label=f"Total\n(Porcentual)", color='brown')  # Marrón para total porcentual
ax4.set_ylabel('Valores Porcentuales')

# Set titles and legends for the second subplot
ax3.set_title(f'PAÍS: CHILE - Totales Absolutos y Porcentuales\n{tema}')
ax3.legend(loc="upper left")
ax4.legend(loc="upper right")

texto_md = """<div style="display: flex; justify-content: space-between;">
  <img src="../assets/per201_1.png" alt="" width="550"></div>
  <img src="../assets/per201_2.png" alt="" width="650">
</div>
"""
display(Markdown(texto_md))

# Show the plot
plt.tight_layout()  # Adjust layout to fit both plots
plt.show()
# Out:
# <div style="display: flex; justify-content: space-between;">
#   <img src="../assets/per201_1.png" alt="" width="550"></div>
#   <img src="../assets/per201_2.png" alt="" width="650">
# </div>

# %%
df_AD
# Out:
#       Dominio      Nombre_Dominio Variable_per  \
# 0    Domain_1  External Relations       per101
# 1    Domain_1  External Relations       per102
# 2    Domain_1  External Relations       per103
# 3    Domain_1  External Relations       per104
# 4    Domain_1  External Relations       per105
# ..        ...                 ...          ...
# 137  Domain 6   Fabric of Society     per608_1
# 138  Domain 6   Fabric of Society     per608_2
# 139  Domain 6   Fabric of Society     per608_3
# 140  Domain_7       Social Groups     per703_1
# 141  Domain_7       Social Groups     per703_2
#
#                                    Detalle_Dominio
# 0          Foreign Special Relationships: Positive
# 1          Foreign Special Relationships: Negative
# 2                                 Anti-Imperialism
# 3                               Military: Positive
# 4                               Military: Negative
# ..                                             ...
# 137             Multiculturalism General: Negative
# 138      Multiculturalism: Immigrants Assimilation
# 139  Multiculturalism: Indigenous rights: Negative
# 140              Agriculture and Farmers: Positive
# 141              Agriculture and Farmers: Negative
#
# [142 rows x 4 columns]

# %%
# Creamos 'df_dominio_y_variables'
columns = ['Nombre_Dominio'] + [f'variable{i}' for i in range(1, 17)]

# Create an empty DataFrame with the specified columns
df_dominio_y_variables = pd.DataFrame(columns=columns)

df_dominio_y_variables
# Out:
# Empty DataFrame
# Columns: [Nombre_Dominio, variable1, variable2, variable3, variable4, variable5, variable6, variable7, variable8, variable9, variable10, variable11, variable12, variable13, variable14, variable15, variable16]
# Index: []

# %% [markdown]
# #### Poblamos df_dominio_y_variables con los nombres de las columnas que se debe agregar para cada dominio

# %%
# Filter df_AD to include only rows where the length of 'Variable_per' is less than or equal to 6
filtered_df_AD = df_AD[df_AD['Variable_per'].str.len() <= 6]

# Create a dictionary to store the data
dominio_dict = {}

# Iterate over the rows of filtered_df_AD
for index, row in filtered_df_AD.iterrows():
    dominio = row['Nombre_Dominio']
    variable = row['Variable_per']
    
    # If the dominio is not in the dictionary, initialize it with an empty list
    if dominio not in dominio_dict:
        dominio_dict[dominio] = []
    
    # Append the variable to the list of the corresponding dominio
    dominio_dict[dominio].append(variable)

# Create a list of dictionaries to convert to a DataFrame
data = []
for dominio, variables in dominio_dict.items():
    # Ensure there are exactly 16 variables, filling with None if necessary
    variables += [None] * (16 - len(variables))
    data.append({'Nombre_Dominio': dominio, **{f'variable{i+1}': variables[i] for i in range(16)}})

# Create the DataFrame
df_dominio_y_variables = pd.DataFrame(data)

# Display the DataFrame
df_dominio_y_variables
# Out:
#                 Nombre_Dominio variable1 variable2 variable3 variable4  \
# 0           External Relations    per101    per102    per103    per104
# 1        Freedom and Democracy    per201    per202    per203    per204
# 2             Political System    per301    per302    per303    per304
# 3                      Economy    per401    per402    per403    per404
# 4  Welfare and Quality of Life    per501    per502    per503    per504
# 5            Fabric of Society    per601    per602    per603    per604
# 6                Social Groups    per701    per702    per703    per704
#
#   variable5 variable6 variable7 variable8 variable9 variable10 variable11  \
# 0    per105    per106    per107    per108    per109     per110       None
# 1      None      None      None      None      None       None       None
# 2    per305      None      None      None      None       None       None
# 3    per405    per406    per407    per408    per409     per410     per411
# 4    per505    per506    per507      None      None       None       None
# 5    per605    per606    per607    per608      None       None       None
# 6    per705    per706      None      None      None       None       None
#
#   variable12 variable13 variable14 variable15 variable16
# 0       None       None       None       None       None
# 1       None       None       None       None       None
# 2       None       None       None       None       None
# 3     per412     per413     per414     per415     per416
# 4       None       None       None       None       None
# 5       None       None       None       None       None
# 6       None       None       None       None       None

# %% [markdown]
# #### Grafiquemos los 7 dominios principales de Manifesto Project, Absolutos vs Porcentuales

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg  # Para cargar la imagen
from PIL import Image  # Alternativa para cargar la imagen si es necesario


# Iterate through each 'Nombre_Dominio' in 'df_dominio_y_variables'
for index, row in df_dominio_y_variables.iterrows():
    dominio = row['Nombre_Dominio']
    
    # Get the list of variables for the current 'Nombre_Dominio'
    variables = [row[f'variable{i+1}'] for i in range(16) if row[f'variable{i+1}'] is not None]
    
    # Sum the values of the corresponding columns in 'df_absolutos_Chile_ponderados'
    df_abs_dominio = df_absolutos_Chile_ponderados[['agno'] + variables].copy()
    df_abs_dominio['Total'] = df_abs_dominio[variables].sum(axis=1)
    
    # Sum the values of the corresponding columns in 'df_porcentual_Chile_ponderados'
    df_por_dominio = df_porcentual_Chile_ponderados[['agno'] + variables].copy()
    df_por_dominio['Total'] = df_por_dominio[variables].sum(axis=1)
    
    texto_md = ""
    # Si el dominio es 'External Relations', agregamos la imagen 'RelExt.png'
    if dominio == 'External Relations':
       texto_md += "<img src='../assets/RelExt.png' alt='' width='800'>"
    
    # texto_md += "</div>"
    
    # Si el dominio es 'Fabric of Society', agregamos la imagen 'Fabric_of_society.png'
    if dominio == 'Fabric of Society':
       texto_md += "<img src='../assets/Fabric_of_society.png' alt='' width='800'>"
    
    texto_md += "</div>"
    
    
    # Mostrar las imágenes antes del gráfico
    display(Markdown(texto_md))
    
    
    # Create a figure with two subplots (one for the plot and one for the image)
    fig, (ax1, ax_img) = plt.subplots(1, 2, figsize=(14, 6), gridspec_kw={'width_ratios': [4, 1]})
    
    # Plot the absolute values on the left axis
    ax1.plot(df_abs_dominio['agno'], df_abs_dominio['Total'], label=f"{dominio} (Absoluto)", color='b')
    ax1.set_xlabel('Año')
    ax1.set_ylabel('Valores Absolutos')
    ax1.set_title(f'PAÍS: CHILE - DOMINIO: {dominio}\nValores Absolutos y Porcentuales')
    ax1.grid(True)
    ax1.legend(loc="upper left")
    
    # Create a second y-axis for the porcentual values
    ax2 = ax1.twinx()
    ax2.plot(df_por_dominio['agno'], df_por_dominio['Total'], label=f"{dominio} (Porcentual)", color='r')
    ax2.set_ylabel('Valores Porcentuales')
    ax2.legend(loc="upper right")
    
    # Load and show the image in the second subplot (outside the plot area)
    img = mpimg.imread('../assets/presidentes.png')  # Cargar la imagen
    ax_img.imshow(img)
    ax_img.axis('off')  # Quitar los ejes de la imagen
    
    # Show the plot
    plt.tight_layout()
    plt.show()
    
    # Insertar una línea negra más gruesa con Markdown y HTML
    display(Markdown('<hr style="border:2px solid black">'))
# Out:
# <img src='../assets/RelExt.png' alt='' width='800'></div>
# <hr style="border:2px solid black">
# </div>
# <hr style="border:2px solid black">
# </div>
# <hr style="border:2px solid black">
# </div>
# <hr style="border:2px solid black">
# </div>
# <hr style="border:2px solid black">
# <img src='../assets/Fabric_of_society.png' alt='' width='800'></div>
# <hr style="border:2px solid black">
# </div>
# <hr style="border:2px solid black">

# %%
# Display the first few rows of the DataFrame
df.head()

# %%
# Corrige nombre de Se
# Count the number of changes
count_changes = df.loc[df['candidatename'].notna() & df['candidatename'].str.contains('Piñera'), 'candidatename'].count()

# Replace the values
df.loc[df['candidatename'].notna() & df['candidatename'].str.contains('Piñera'), 'candidatename'] = 'Sebastián Piñera Echeñique'

# Print the number of changes
print(f"Number of changes: {count_changes}")

# %% [markdown]
# #### Crear campo 'agno' para registrar el año del programa de gobierno

# %%
# Insert column 'agno' into the dataframe, of type int, to the right of column 'date'
df.insert(df.columns.get_loc('date') + 1, 'agno', df['edate'].str[-4:].astype(int))

# List unique values of new column 'agno'
unique_agno_values = df['agno'].unique()
#print(unique_agno_values)

# %%
# cargar Analytical_Data
df_AD = pd.read_excel('data/Analytical_Data.xlsx')
df_AD.head()

# %%
# Create a list of column names that begin with 'per' and have a digit in position 4
per_columns = ['countryname', 'candidatename', 'agno', 'presvote'] + [col for col in df.columns if col.startswith('per') and col[3].isdigit()]
#per_columns

# %% [markdown]
# #### PROMEDIO PONDERADO: en 'df' filtramos registros de Chile, separamos por año de elección y calculamos valores representativos basados en el promedio ponderado por el % obtenido en la elección presidencial (presvote)

# %%
# Filter df by 'countryname' == 'Chile'
df_Chile = df[df['countryname'] == 'Chile']

df_Chile = df_Chile.sort_values(by='agno')

# Create a list of column names that begin with 'per' and have a digit in position 4
per_columns_4digit = [col for col in df.columns if col.startswith('per') and col[3].isdigit()]

# Group by column 'agno' and calculate the weighted average of each column in 'per_columns_4digit' using column 'presvote' as weights
df_Chile_ponderado = df_Chile.groupby('agno').apply(
    lambda x: pd.Series({col: np.average(x[col], weights=x['presvote']) for col in per_columns_4digit})
).reset_index()

# Display the results
df_Chile_ponderado

# %% [markdown]
# #### INCLUSIÓN Y MINORÍAS (503, 705, 201_2)

# %%
# Define variables for the columns
tema = "INCLUSIÓN y MINORÍAS"
col_1 = 'per503'
col_2 = 'per705'
col_3 = 'per201_2'

# Select columns from df_Chile_ponderado
df_Chile_inclymin = df_Chile_ponderado[['agno', col_1, col_2, col_3]]

# Add a new column 'Total' with the sum of columns
df_Chile_inclymin['Total'] = df_Chile_inclymin[col_1] + df_Chile_inclymin[col_2] + df_Chile_inclymin[col_3]

# Get the column names excluding 'agno'
columns_to_lookup = df_Chile_inclymin.columns[df_Chile_inclymin.columns != 'agno']
detalle_dominio_dict = {}

# Loop through the columns and get the corresponding 'Detalle_Dominio' from 'df_AD'
for col in columns_to_lookup:
    detalle_dominio = df_AD.loc[df_AD['Variable_per'] == col, 'Detalle_Dominio'].values
    if len(detalle_dominio) > 0:
        detalle_dominio_dict[col] = detalle_dominio[0]

# Update the plot labels with details from the dictionary
label_col_1 = f"{col_1} ({detalle_dominio_dict.get(col_1, 'No Info')})"
label_col_2 = f"{col_2} ({detalle_dominio_dict.get(col_2, 'No Info')})"
label_col_3 = f"{col_3} ({detalle_dominio_dict.get(col_3, 'No Info')})"
label_total = f"Total ({col_1} + {col_2} + {col_3})"

texto_md = """<div style="display: flex; justify-content: space-between;">
  <img src="../assets/per503.png" alt="" width="450">
  <img src="../assets/per705.png" alt="" width="450"></div>
</div>
<img src="../assets/per201_2.png" alt="" width="500">"""
display(Markdown(texto_md))

# Plot columns
plt.figure(figsize=(10, 6))
plt.plot(df_Chile_inclymin['agno'], df_Chile_inclymin[col_1], label=label_col_1)
plt.plot(df_Chile_inclymin['agno'], df_Chile_inclymin[col_2], label=label_col_2)
plt.plot(df_Chile_inclymin['agno'], df_Chile_inclymin[col_3], label=label_col_3)
plt.plot(df_Chile_inclymin['agno'], df_Chile_inclymin['Total'], label=label_total)

plt.xlabel('Año')
plt.ylabel('Ponderado')
plt.title(f'PAÍS: CHILE\n{tema}')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Comentario a Inclusión y Minorías:
# * La línea del Total muestra que el aspecto "Inclusión y Minorías" ha ido disminuyendo porcentualmente en las menciones de los programas de gobierno entre 1989 y 2021. Sin embargo es el segundo más importante de los aspectos en análisis, lo cual se puede apreciar en el gráfico resumen.

# %% [markdown]
# #### ORDEN y CORRUPCIÓN (605_1, -605_2, per304)

# %%
# Define variables for the columns
tema = "ORDEN Y CORRUPCIÓN"
col_1 = 'per605_1'
col_2 = 'per605_2'
col_3 = 'per304'

# Select columns from df_Chile_ponderado
df_Chile_orden = df_Chile_ponderado[['agno', col_1, col_2, col_3]]

# Add a new column 'Total' with the sum of columns
df_Chile_orden['Total'] = df_Chile_orden[col_1] - df_Chile_orden[col_2] + df_Chile_orden[col_3]

# Get the column names excluding 'agno'
columns_to_lookup = df_Chile_orden.columns[df_Chile_orden.columns != 'agno']
detalle_dominio_dict = {}

# Loop through the columns and get the corresponding 'Detalle_Dominio' from 'df_AD'
for col in columns_to_lookup:
    detalle_dominio = df_AD.loc[df_AD['Variable_per'] == col, 'Detalle_Dominio'].values
    if len(detalle_dominio) > 0:
        detalle_dominio_dict[col] = detalle_dominio[0]

# Update the plot labels with details from the dictionary
label_col_1 = f"{col_1} ({detalle_dominio_dict.get(col_1, 'No Info')})"
label_col_2 = f"{col_2} ({detalle_dominio_dict.get(col_2, 'No Info')})"
label_col_3 = f"{col_3} ({detalle_dominio_dict.get(col_3, 'No Info')})"
label_total = f"Total ({col_1} - {col_2} + {col_3})"

texto_md = """<div style="display: flex; justify-content: space-between;">
  <img src="../assets/per605_1-per605_2.png" alt="" width="450"></div>
  <img src="../assets/per304.png" alt="" width="450">
</div>

"""
display(Markdown(texto_md))

# Plot columns
plt.figure(figsize=(10, 6))
plt.plot(df_Chile_orden['agno'], df_Chile_orden[col_1], label=label_col_1)
plt.plot(df_Chile_orden['agno'], df_Chile_orden[col_2], label=label_col_2)
plt.plot(df_Chile_orden['agno'], df_Chile_orden[col_3], label=label_col_3)
plt.plot(df_Chile_orden['agno'], df_Chile_orden['Total'], label=label_total)

plt.xlabel('Año')
plt.ylabel('Ponderado')
plt.title(f'PAÍS: CHILE\n{tema} ({col_1} - {col_2} + {col_3})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Comentario a ORDEN Y CORRUPCIÓN
# * Se puede apreciar claramente la importancia que ha ido adquiriendo este aspecto en Chile, variando desde 1,1 en 1989 a 5,2 en 2021 (4.8 veces). Esto ha sido impulsado por un fuerte aumento de las menciones a dotar de mayores recursos a las policías y mayor rigurosidad en los tribunales. Debe mencionarse la disminución de las menciones a la corrupción política y al abuso de este poder.

# %% [markdown]
# #### MEDIO AMBIENTE Y SOSTENIBILIDAD (501, 416_2)

# %%
# Define variables for the columns
tema = "MEDIO AMBIENTE Y SOSTENIBILIDAD"
col_1 = 'per501'
col_2 = 'per416_2'

# Select columns from df_Chile_ponderado
df_Chile_medioambiente = df_Chile_ponderado[['agno', col_1, col_2]]

# Add a new column 'Total' with the sum of columns
df_Chile_medioambiente['Total'] = df_Chile_medioambiente[col_1] + df_Chile_medioambiente[col_2]

# Get the column names excluding 'agno'
columns_to_lookup = df_Chile_medioambiente.columns[df_Chile_medioambiente.columns != 'agno']
detalle_dominio_dict = {}

# Loop through the columns and get the corresponding 'Detalle_Dominio' from 'df_AD'
for col in columns_to_lookup:
    detalle_dominio = df_AD.loc[df_AD['Variable_per'] == col, 'Detalle_Dominio'].values
    if len(detalle_dominio) > 0:
        detalle_dominio_dict[col] = detalle_dominio[0]

# Update the plot labels with details from the dictionary
label_col_1 = f"{col_1} ({detalle_dominio_dict.get(col_1, 'No Info')})"
label_col_2 = f"{col_2} ({detalle_dominio_dict.get(col_2, 'No Info')})"
label_total = f"Total ({col_1} + {col_2})"

texto_md = """<div style="display: flex; justify-content: space-between;">
  <img src="../assets/per501.png" alt="" width="550"></div>
  <img src="../assets/per416_2.png" alt="" width="450">
</div>
"""
display(Markdown(texto_md))

# Plot columns
plt.figure(figsize=(10, 6))
plt.plot(df_Chile_medioambiente['agno'], df_Chile_medioambiente[col_1], label=label_col_1)
plt.plot(df_Chile_medioambiente['agno'], df_Chile_medioambiente[col_2], label=label_col_2)
plt.plot(df_Chile_medioambiente['agno'], df_Chile_medioambiente['Total'], label=label_total)

plt.xlabel('Año')
plt.ylabel('Ponderado')
plt.title(f'PAÍS: CHILE\n{tema} ({col_1} + {col_2})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Comentario a MEDIO AMBIENTE Y SOSTENIBILIDAD
# * Este es el aspecto que evoluciona más fuerte de todos, y en todos sus componentes.

# %% [markdown]
# #### PUEBLOS ORIGINARIOS (607_3, 608_3)

# %%
# Define variables for the columns
tema = "PUEBLOS ORIGINARIOS"
col_1 = 'per607_3'
col_2 = 'per608_3'

# Select columns from df_Chile_ponderado
df_Chile_poriginarios = df_Chile_ponderado[['agno', col_1, col_2]]

# Add a new column 'Total' with the sum of columns
df_Chile_poriginarios['Total'] = df_Chile_poriginarios[col_1] - df_Chile_poriginarios[col_2]

# Get the column names excluding 'agno'
columns_to_lookup = df_Chile_poriginarios.columns[df_Chile_poriginarios.columns != 'agno']
detalle_dominio_dict = {}

# Loop through the columns and get the corresponding 'Detalle_Dominio' from 'df_AD'
for col in columns_to_lookup:
    detalle_dominio = df_AD.loc[df_AD['Variable_per'] == col, 'Detalle_Dominio'].values
    if len(detalle_dominio) > 0:
        detalle_dominio_dict[col] = detalle_dominio[0]

# Update the plot labels with details from the dictionary
label_col_1 = f"{col_1} ({detalle_dominio_dict.get(col_1, 'No Info')})"
label_col_2 = f"{col_2} ({detalle_dominio_dict.get(col_2, 'No Info')})"
label_total = f"Total ({col_1} - {col_2})"

texto_md = """<div style="display: flex; justify-content: space-between;">
  <img src="../assets/per607_3.png" alt="" width="550"></div>
  <img src="../assets/per608_3.png" alt="" width="550">
</div>
"""
display(Markdown(texto_md))

# Plot columns
plt.figure(figsize=(10, 6))
plt.plot(df_Chile_poriginarios['agno'], df_Chile_poriginarios[col_1], label=label_col_1)
plt.plot(df_Chile_poriginarios['agno'], df_Chile_poriginarios[col_2], label=label_col_2)
plt.plot(df_Chile_poriginarios['agno'], df_Chile_poriginarios['Total'], label=label_total)

plt.xlabel('Año')
plt.ylabel('Ponderado')
plt.title(f'PAÍS: CHILE\n{tema} ({col_1} - {col_2})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Comentario a PUEBLOS ORIGINARIOS
# * Luego de tener un crecimiento fuerte y sostenido entre 1989 y 2008, PUEBLOS ORIGINARIOS ha ido perdiendo fuertemente participación en las menciones en los programas de gobierno.

# %% [markdown]
# #### DERECHOS HUMANOS (per201_1, per201_2)

# %%
# Define variables for the columns
tema = "DERECHOS HUMANOS"
col_1 = 'per201_1'
col_2 = 'per201_2'

# Select columns from df_Chile_ponderado
df_Chile_hr = df_Chile_ponderado[['agno', col_1, col_2]]

# Add a new column 'Total' with the sum of columns
df_Chile_hr['Total'] = df_Chile_hr[col_1] + df_Chile_hr[col_2]

# Get the column names excluding 'agno'
columns_to_lookup = df_Chile_hr.columns[df_Chile_hr.columns != 'agno']
detalle_dominio_dict = {}

# Loop through the columns and get the corresponding 'Detalle_Dominio' from 'df_AD'
for col in columns_to_lookup:
    detalle_dominio = df_AD.loc[df_AD['Variable_per'] == col, 'Detalle_Dominio'].values
    if len(detalle_dominio) > 0:
        detalle_dominio_dict[col] = detalle_dominio[0]

# Update the plot labels with details from the dictionary
label_col_1 = f"{col_1} ({detalle_dominio_dict.get(col_1, 'No Info')})"
label_col_2 = f"{col_2} ({detalle_dominio_dict.get(col_2, 'No Info')})"
label_total = f"Total ({col_1} + {col_2})"

texto_md = """<div style="display: flex; justify-content: space-between;">
  <img src="../assets/per201_1_2.png" alt="" width="550"></div>
</div>
"""
display(Markdown(texto_md))

# Plot columns
plt.figure(figsize=(10, 6))
plt.plot(df_Chile_hr['agno'], df_Chile_hr[col_1], label=label_col_1)
plt.plot(df_Chile_hr['agno'], df_Chile_hr[col_2], label=label_col_2)
plt.plot(df_Chile_hr['agno'], df_Chile_hr['Total'], label=label_total)

plt.xlabel('Año')
plt.ylabel('Ponderado')
plt.title(f'PAÍS: CHILE\n{tema} ({col_1} + {col_2})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Comentario a DERECHOS HUMANOS:
# * Este aspecto ha ido perdiendo participación desde 1989 a 2021, pero crece en forma sostenida desde 2005.

# %% [markdown]
# #### INMIGRACIÓN (602_2, 607_1)

# %%
# Define variables for the columns
tema = "INMIGRACIÓN"
col_1 = 'per602_2'
col_2 = 'per607_1'
#col_3 = 'per201_2'

# Select columns from df_Chile_ponderado
df_Chile_inmigracion = df_Chile_ponderado[['agno', col_1, col_2]] #col_3

# Add a new column 'Total' with the sum of columns
df_Chile_inmigracion['Total'] = df_Chile_inmigracion[col_1] + df_Chile_inmigracion[col_2] #+ df_Chile_inmigracion[col_3]

# Get the column names excluding 'agno'
columns_to_lookup = df_Chile_inmigracion.columns[df_Chile_inmigracion.columns != 'agno']
detalle_dominio_dict = {}

# Loop through the columns and get the corresponding 'Detalle_Dominio' from 'df_AD'
for col in columns_to_lookup:
    detalle_dominio = df_AD.loc[df_AD['Variable_per'] == col, 'Detalle_Dominio'].values
    if len(detalle_dominio) > 0:
        detalle_dominio_dict[col] = detalle_dominio[0]

# Update the plot labels with details from the dictionary
label_col_1 = f"{col_1} ({detalle_dominio_dict.get(col_1, 'No Info')})"
label_col_2 = f"{col_2} ({detalle_dominio_dict.get(col_2, 'No Info')})"
#label_col_3 = f"{col_3} ({detalle_dominio_dict.get(col_3, 'No Info')})"
label_total = f"Total ({col_1} + {col_2})" # + {col_3})"

texto_md = """<div style="display: flex; justify-content: space-between;">
  <img src="../assets/per602_2.png" alt="" width="550"></div>
  <img src="../assets/per607_1.png" alt="" width="550">
</div>
"""
display(Markdown(texto_md))

# Plot columns
plt.figure(figsize=(10, 6))
plt.plot(df_Chile_inmigracion['agno'], df_Chile_inmigracion[col_1], label=label_col_1)
plt.plot(df_Chile_inmigracion['agno'], df_Chile_inmigracion[col_2], label=label_col_2)
#plt.plot(df_Chile_inmigracion['agno'], df_Chile_inmigracion[col_3], label=label_col_3)
plt.plot(df_Chile_inclymin['agno'], df_Chile_inmigracion['Total'], label=label_total)

plt.xlabel('Año')
plt.ylabel('Ponderado')
plt.title(f'PAÍS: CHILE\n{tema}')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Comentario a INMIGRACIÓN
# * Este aspecto está definido por menciones en favor de la inmigración. Llama la atención el repunte fuerte en 2008 y luego la baja brusca en 2017, posiblemente por la asociación de la inmigración con la seguridad.

# %% [markdown]
# #### MORAL TRADICIONAL (603, 604)

# %%
# Define variables for the columns
tema = "MORAL TRADICIONAL"
col_1 = 'per603'
col_2 = 'per604'
#col_3 = 'per201_2'

# Select columns from df_Chile_ponderado
df_Chile_moral = df_Chile_ponderado[['agno', col_1, col_2]] #col_3

# Add a new column 'Total' with the sum of columns
df_Chile_moral['Total'] = df_Chile_moral[col_1] - df_Chile_moral[col_2] #+ df_Chile_moral[col_3]

# Get the column names excluding 'agno'
columns_to_lookup = df_Chile_moral.columns[df_Chile_moral.columns != 'agno']
detalle_dominio_dict = {}

# Loop through the columns and get the corresponding 'Detalle_Dominio' from 'df_AD'
for col in columns_to_lookup:
    detalle_dominio = df_AD.loc[df_AD['Variable_per'] == col, 'Detalle_Dominio'].values
    if len(detalle_dominio) > 0:
        detalle_dominio_dict[col] = detalle_dominio[0]

# Update the plot labels with details from the dictionary
label_col_1 = f"{col_1} ({detalle_dominio_dict.get(col_1, 'No Info')})"
label_col_2 = f"{col_2} ({detalle_dominio_dict.get(col_2, 'No Info')})"
#label_col_3 = f"{col_3} ({detalle_dominio_dict.get(col_3, 'No Info')})"
label_total = f"Total ({col_1} - {col_2})" # + {col_3})"

texto_md = """<div style="display: flex; justify-content: space-between;">
  <img src="../assets/per603_604.png" alt="" width="550"></div>
</div>
"""
display(Markdown(texto_md))

# Plot columns
plt.figure(figsize=(10, 6))
plt.plot(df_Chile_moral['agno'], df_Chile_moral[col_1], label=label_col_1)
plt.plot(df_Chile_moral['agno'], df_Chile_moral[col_2], label=label_col_2)
#plt.plot(df_Chile_moral['agno'], df_Chile_moral[col_3], label=label_col_3)
plt.plot(df_Chile_moral['agno'], df_Chile_moral['Total'], label=label_total)

plt.xlabel('Año')
plt.ylabel('Ponderado')
plt.title(f'PAÍS: CHILE\n{tema}')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### Comentario a MORAL TRADICIONAL:
# * Puede observarse como a partir de 2005 comienzan a ser mencionados los aspecto relacionados con el divorcio, el aborto y la concepción de familias con composición diferente a la tradicional en Chile.

# %% [markdown]
# #### GRÁFICO RESUMEN

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))

# Plot
plt.plot(df_Chile_poriginarios['agno'], df_Chile_poriginarios['Total'], label='Pueblos Originarios')
plt.plot(df_Chile_orden['agno'], df_Chile_orden['Total'], label='Orden y Corrupción')
plt.plot(df_Chile_medioambiente['agno'], df_Chile_medioambiente['Total'], label='Medio Ambiente y Sostenibilidad')
plt.plot(df_Chile_inclymin['agno'], df_Chile_inclymin['Total'], label='Inclusión y Minorías')
plt.plot(df_Chile_hr['agno'], df_Chile_hr['Total'], label='Derechos Humanos')
plt.plot(df_Chile_inmigracion['agno'], df_Chile_inmigracion['Total'], label='Inmigración')
plt.plot(df_Chile_moral['agno'], df_Chile_moral['Total'], label='Moral Tradicional')

# Etiquetas al final de cada línea
plt.annotate('Pueblos Originarios', xy=(df_Chile_poriginarios['agno'].values[-1], df_Chile_poriginarios['Total'].values[-1]), xytext=(5, 0), textcoords='offset points')
plt.annotate('Orden y Corrupción', xy=(df_Chile_orden['agno'].values[-1], df_Chile_orden['Total'].values[-1]), xytext=(5, 0), textcoords='offset points')
plt.annotate('Medio Ambiente y Sostenibilidad', xy=(df_Chile_medioambiente['agno'].values[-1], df_Chile_medioambiente['Total'].values[-1]), xytext=(5, 0), textcoords='offset points')
plt.annotate('Inclusión y Minorías', xy=(df_Chile_inclymin['agno'].values[-1], df_Chile_inclymin['Total'].values[-1]), xytext=(5, 0), textcoords='offset points')
plt.annotate('Derechos Humanos', xy=(df_Chile_hr['agno'].values[-1], df_Chile_hr['Total'].values[-1]), xytext=(5, 0), textcoords='offset points')
plt.annotate('Inmigración', xy=(df_Chile_inmigracion['agno'].values[-1], df_Chile_inmigracion['Total'].values[-1]), xytext=(5, 0), textcoords='offset points')
plt.annotate('Moral Tradicional', xy=(df_Chile_moral['agno'].values[-1], df_Chile_moral['Total'].values[-1]), xytext=(5, 0), textcoords='offset points')

# Configuración del gráfico
plt.xlabel('Año')
plt.ylabel('Total Ponderado')
plt.title('Comparación de Diferentes Aspectos en Chile')
plt.legend().set_visible(False)  # Oculta la leyenda ya que las etiquetas están al final de las líneas
plt.grid(True)

plt.show()

# %% [markdown]
# #### COMENTARIO GENERAL:
# * Las conclusiones mencionadas en los gráficos individuales (resumidos en este cuadro comparativo), son consistentes con lo que se observa en Chile. Es posible que se pueda incorporar más variables a los aspectos mencionados de manera de tener una mejor representación, como también agregar más aspectos para analizar (Derechos Sociales, Economía, Sistema Político y otros).
# *
# * En resumen, en base a este análisis, es posible sostener que el dataset habla de Chile como Chile es.

# %% [markdown]
# #### CHILE: TODOS LOS DOMINIOS

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Initialize an empty dataframe to store the results
df_Chile_dom = pd.DataFrame()

# Loop through each unique 'Dominio' in 'df_AD'
for dominio in df_AD['Dominio'].unique():
    # Create list 'columnas_per' with values of 'Variable_per' for that 'Dominio' considering only columns with name length == 6
    columnas_per = df_AD[(df_AD['Dominio'] == dominio) & (df_AD['Variable_per'].str.len() == 6)]['Variable_per'].tolist()
    
    # Sum the columns with names in 'columnas_per' for each 'agno' in 'df_Chile_ponderado'
    df_Chile_ponderado['tot_dom'] = df_Chile_ponderado[columnas_per].sum(axis=1)
    
    # Create a temporary dataframe with 'agno', 'Dominio', and 'tot_dom'
    temp_df = df_Chile_ponderado[['agno', 'tot_dom']].copy()
    temp_df['Dominio'] = dominio
    
    # Append the temporary dataframe to 'df_Chile_dom'
    df_Chile_dom = pd.concat([df_Chile_dom, temp_df], ignore_index=True)
    
    # Reset 'columnas_per' for the next loop iteration
    columnas_per = []

# Merge 'df_Chile_dom' with 'df_AD' to get 'Nombre_Dominio'
df_Chile_dom = df_Chile_dom.merge(df_AD[['Dominio', 'Nombre_Dominio']].drop_duplicates(), on='Dominio', how='left')

# Plot the dataframe 'df_Chile_dom' with 'agno' on the horizontal axis and 'tot_dom' on the vertical axis
plt.figure(figsize=(12, 8))

for dominio in df_Chile_dom['Dominio'].unique():
    subset = df_Chile_dom[df_Chile_dom['Dominio'] == dominio]
    
    # Plot the line for each 'Dominio'
    plt.plot(subset['agno'], subset['tot_dom'], label=subset['Nombre_Dominio'].iloc[0])
    
    # Check if 'Dominio' is 'Social Groups' or 'Freedom and Democracy' and place the label at the end
    if dominio in ['Domain_7', 'Domain_1']:
        plt.text(subset['agno'].iloc[-1], subset['tot_dom'].iloc[-1], subset['Nombre_Dominio'].iloc[0], 
                 fontsize=9, ha='left', va='center')
    else:
        # Place the label at the start for other dominios
        plt.text(subset['agno'].iloc[0], subset['tot_dom'].iloc[0], subset['Nombre_Dominio'].iloc[0], 
                 fontsize=9, ha='right', va='center')

# Configuración del gráfico
plt.xlabel('Año')
plt.ylabel('Total Dominio')
plt.title('Total Dominio por Año en Chile')
plt.legend()
plt.grid(True)
plt.show()
