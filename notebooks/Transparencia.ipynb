# %%
import pandas as pd
# Crear el DataFrame 'df_transparencia'
df_transparencia = pd.read_excel('./data/df_transparencia_.xlsx')
display(df_transparencia.head())
# Out:
#            Country Name  cluster  2012  2013  2014  2015  2016  2017  2018  \
# 0               Armenia        0    34    36    37    35    33    35    35
# 1             Australia        0    85    81    80    79    79    77    77
# 2               Austria        2    69    69    72    76    75    75    76
# 3  Bosnia y Herzegovina        3    42    42    39    38    39    38    38
# 4                Brasil        2    43    42    43    38    40    37    35
#
#    2019  2020  2021  2022  2023
# 0    42    49    49    46    47
# 1    77    77    73    75    75
# 2    77    76    74    71    71
# 3    36    35    35    34    35
# 4    35    38    38    38    36

# %%
df_transparencia.columns
# Out:
# Index(['Country Name', 'cluster', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Convertir años a formato numérico para facilitar operaciones
year_columns = [str(year) for year in range(2012, 2024)]

# Agrupar por 'cluster' y calcular los promedios de las columnas de años
cluster_means = df_transparencia.groupby('cluster')[year_columns].mean()

# Crear un gráfico de líneas
plt.figure(figsize=(10, 6))
for cluster in cluster_means.index:
    plt.plot(year_columns, cluster_means.loc[cluster], label=f'Cluster {cluster}')

# Configurar el gráfico
plt.title('Promedios por Cluster (2012-2023)\n100=Very Clean    0 = Highly Corrupt', fontsize=14)
plt.xlabel('Año', fontsize=12)
plt.ylabel('Promedio', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Cluster')
plt.grid(True)
plt.tight_layout()

# Mostrar el gráfico
plt.show()
